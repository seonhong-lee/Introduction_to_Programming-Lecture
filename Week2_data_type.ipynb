# %% [markdown]
# ## 파이썬의 자료형

# %% [markdown]
# *   기본 자료형 출력

# %%
print("안녕하세요, 첫 번째 파이썬 프로그램입니다.")
# Out:
# 안녕하세요, 첫 번째 파이썬 프로그램입니다.

# %%
print(2 + 5)
# Out:
# 7

# %%
print(2.3 + 5.2)
# Out:
# 7.5

# %%
# 아래 코드를 실행하면, 오류가 발생
# print("가나다" - "가나")

# %%
print(0.3)
# Out:
# 0.3

# %%
print(7.2354)
# Out:
# 7.2354

# %%
print(0.3)
# Out:
# 0.3

# %%
print(.3)
# Out:
# 0.3

# %%
print(3.0)
# Out:
# 3.0

# %%
print(3.)
# Out:
# 3.0

# %%
print(1.0e3)
# Out:
# 1000.0

# %%
print(1.0E3)
# Out:
# 1000.0

# %%
print(1.0e-3)
# Out:
# 0.001

# %%
print(1.2E10)
# Out:
# 12000000000.0

# %%
print(0.001 + 0.0001)
# Out:
# 0.0011

# %%
print(0.001 + 0.1e-3) # 0.001 + 0.0001
# Out:
# 0.0011

# %%
print(0.001 * 0.00001)
# Out:
# 1e-08

# %%
print(0.8323234243345 * 0.00000000001)
# Out:
# 8.323234243345e-12

# %%
print("파이썬 문자열입니다")
# Out:
# 파이썬 문자열입니다

# %%
print('동일하게 취급되는 파이썬 문자열입니다.')
# Out:
# 동일하게 취급되는 파이썬 문자열입니다.

# %%
# 아래 코드를 실행하면, 오류가 발생
# "문자열 아닙니다'

# %%
print('다음 문장은 인용된 문구입니다. "영호가 괜찮다고 말했습니다."')
# Out:
# 다음 문장은 인용된 문구입니다. "영호가 괜찮다고 말했습니다."

# %%
print("다음 문장은 인용된 문구입니다. '영호가 괜찮다고 말했습니다'")
# Out:
# 다음 문장은 인용된 문구입니다. '영호가 괜찮다고 말했습니다'

# %%
print("""
여러 줄에 걸친
문자열을
표현하려면
따옴표 세 개로 묶으면 된다.
""")
# Out:
# 여러 줄에 걸친
# 문자열을
# 표현하려면
# 따옴표 세 개로 묶으면 된다.

# %%
print('''
여러 줄에 걸친
문자열을
표현하려면
따옴표 세 개로 묶으면 된다.
''')
# Out:
# 여러 줄에 걸친
# 문자열을
# 표현하려면
# 따옴표 세 개로 묶으면 된다.

# %%
print("백슬래시를 표현하려면 \\를 써야 합니다.")
# Out:
# 백슬래시를 표현하려면 \를 써야 합니다.

# %%
print("첫 \t번째 문장 \n새로운 문장")
# Out:
# 첫 	번째 문장
# 새로운 문장

# %%
print("문자열 상수에서 큰 따옴표 \" 표현 방법")
# Out:
# 문자열 상수에서 큰 따옴표 " 표현 방법

# %%
print('문자열 상수에서 작은 따옴표 \' 표현 방법')
# Out:
# 문자열 상수에서 작은 따옴표 ' 표현 방법

# %%
print('문자열 상수에서 큰 따옴표 " 표현 방법')
# Out:
# 문자열 상수에서 큰 따옴표 " 표현 방법

# %%
print("문자열 상수에서 작은 따옴표 ' 표현 방법")
# Out:
# 문자열 상수에서 작은 따옴표 ' 표현 방법

# %%
print(2 > 3)
# Out:
# False

# %%
print(2 < 3)
# Out:
# True

# %%
print(None)
# Out:
# None

# %%
print(type("안녕하세요"))
# Out:
# <class 'str'>

# %%
print(type('안녕하세요'))
# Out:
# <class 'str'>

# %%
print(type(2))
# Out:
# <class 'int'>

# %%
print(type(2.3))
# Out:
# <class 'float'>

# %%
print(type(3 > 2))
# Out:
# <class 'bool'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(int("123"))
# Out:
# 123

# %%
print(type(int("123")))
# Out:
# <class 'int'>

# %%
print(int(123.6))
# Out:
# 123

# %%
# 아래 코드를 실행하면, 오류가 발생
# print(int("123.6"))

# %%
# 아래 코드를 실행하면, 오류가 발생
# print(int("123a"))

# %%
# 아래 코드를 실행하면, 오류가 발생
# print(int("a123"))

# %%
print(float("123.2")) # 실수형 문자열을 실수값으로 변환
# Out:
# 123.2

# %%
print(float("123")) # 정수형 문자열도 실수값으로 변환
# Out:
# 123.0

# %%
print(float(123)) # 정수를 전달해도 실수값으로 변환
# Out:
# 123.0

# %%
# 아래 코드를 실행하면, 오류가 발생
# print(float("123.0a"))

# %%
# 아래 코드를 실행하면, 오류가 발생
# print(float("a123.0"))

# %%
print(str(123.4))
# Out:
# 123.4

# %%
print(type(str(123.4)))
# Out:
# <class 'str'>

# %%
print(type(123.4))
# Out:
# <class 'float'>

# %%
print(str(True)) # 불린값을 문자열로 변환
# Out:
# True

# %%
print(str(3 < 2))
# Out:
# False

# %%
print(2 + 5)
print(2 - 5)
print(2 * 5)
print(5 / 2)
print(5 // 2)
print(5 % 2)
print(2 / 5)
print(2 // 5)
print(2 ** 5)
# Out:
# 7
# -3
# 10
# 2.5
# 2
# 1
# 0.4
# 0
# 32

# %%
print(2.3 + 5.2)
print(2.3 - 5)
print(2.3 * 5.1)
print(5.2 / 2)
print(5.2 // 2.3)
print(6.1 // 2.1)
print(5.2 % 2.3)
print(2.3 / 5.2)
print(2.3 ** 5.2)
# Out:
# 7.5
# -2.7
# 11.729999999999999
# 2.6
# 2.0
# 2.0
# 0.6000000000000005
# 0.44230769230769224
# 76.02995742489944

# %%
print(2 * 3 + 2)
# Out:
# 8

# %%
print(2 * (3 + 2))
# Out:
# 10

# %%
# 2 * [3 + {4 / (2 + 3)} * 4]
print(2 * (3 + (4 / (2 + 3)) * 4))
# Out:
# 12.4

# %%
print(2 + 3 * 4 ** 2)
# Out:
# 50

# %%
print(((2 + 3) * 4) ** 2)
# Out:
# 400

# %%
print("가나다" + "라마바")
# Out:
# 가나다라마바

# %%
print(str(2023) + "10월 2일 월요일은 임시 공휴일로 지정 되었습니다.")
# Out:
# 202310월 2일 월요일은 임시 공휴일로 지정 되었습니다.

# %%
print("a" * 5)
# Out:
# aaaaa

# %%
print("하" * 5)
# Out:
# 하하하하하

# %%
print("안녕" * 5)
# Out:
# 안녕안녕안녕안녕안녕

# %%
print("갈대가 " + "흔들 " * 2)
# Out:
# 갈대가 흔들 흔들

# %%
print(("더운 " + "여름날 ") * 2)
# Out:
# 더운 여름날 더운 여름날

# %% [markdown]
# *   실습문제4: (17.62 X 30) / (243.12 + 30)을 계산하는 코드를 작성하고 결과를 화면에 출력한다.

# %%
(17.62 * 30) / (243.12 + 30)
# Out:
# 1.935413005272408

# %%
print((17.62 * 30) / (243.12 + 30))
# Out:
# 1.935413005272408

# %% [markdown]
# *   실습문제5: 아이돌 가수들의 후크송처럼 반복되는 가사들이 있다고 가정한다.
# 다음은 노래 가사에서 반복되는 부분이라고 가정한다. 이부분이 세 번 나타나야 한다.
#
# *   디비딥 디비딥 딥디비딥
#
# *   디비디비딥 딥디비딥
#
# *   디비딥 디비딥 딥디비딥

# %%
print('''디비딥 디비딥 딥디비딥
디비디비딥 딥디비딥
디비딥 디비딥 딥디비딥
''' * 3)
# Out:
# 디비딥 디비딥 딥디비딥
# 디비디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥

# %%
print("디비딥 디비딥 딥디비딥\n디비디비딥 딥디비딥\n디비딥 디비딥 딥디비딥\n"* 3)
# Out:
# 디비딥 디비딥 딥디비딥
# 디비디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥
# 디비디비딥 딥디비딥
# 디비딥 디비딥 딥디비딥

# %% [markdown]
# # Reference: 본 코드는 길벗 출판사의 "파이썬의 정석" 책의 코드를 수업형식에 맞게 응용한 코드입니다.
