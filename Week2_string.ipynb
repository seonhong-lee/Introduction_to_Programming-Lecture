# %% [markdown]
# ## 문자열

# %% [markdown]
# *   문자열 길이 확인

# %%
print("hello")
print(len("hello"))
# Out:
# hello
# 5

# %% [markdown]
# *   문자열 검색

# %%
print("Hello World".startswith('H'))
# Out:
# True

# %%
print("Hello World".startswith('W'))
# Out:
# False

# %%
print("Hello World".startswith('h'))
# Out:
# False

# %%
print("Hello World".startswith('Hello'))
# Out:
# True

# %%
print("Hello World".startswith('Hel'))
# Out:
# True

# %%
print("Hello World".startswith('HEllo'))
# Out:
# False

# %%
print("Hello World".startswith('H'))
# Out:
# True

# %%
print("Hello World".startswith('h'))
# Out:
# False

# %%
print("Hello World".endswith('d'))
# Out:
# True

# %%
print("Hello World".endswith('D'))
# Out:
# False

# %%
print("BeutufulImage.png".endswith(".png"))
# Out:
# True

# %% [markdown]
# *   문자열에 특정 문자열이 포함되었는지 확인하기

# %%
print("Wor" in "Hello World")
# Out:
# True

# %%
print("wor" in "Hello World")
# Out:
# False

# %% [markdown]
# *   문자열의 양끝에서 문자가 제거된 새로운 문자열 생성

# %%
print("hello    \t\n")
# Out:
# hello

# %%
print("hello  1  \t\n".strip())
# Out:
# hello  1

# %%
print("이선홍의 프로그래밍입문".strip("이"))
# Out:
# 선홍의 프로그래밍입문

# %%
print("이선홍의 프로그래밍입문".strip("이선"))
# Out:
# 홍의 프로그래밍입문

# %%
print("이선홍의 프로그래밍입문".strip("이문선입"))
# Out:
# 홍의 프로그래밍

# %%
print("hello  1  \t\n".lstrip())
# Out:
# hello  1

# %%
print("hello    \t\n".lstrip("he"))
# Out:
# llo

# %%
print("hello  1  \t\n".rstrip())
# Out:
# hello  1

# %%
print("가나다hello가나다".rstrip("가나다"))
# Out:
# 가나다hello

# %% [markdown]
# *   문자열 일부를 다른 문자열로 치환해서 문자열 생성

# %%
print("뜨거운 커피".replace("뜨거운", "차가운"))
# Out:
# 차가운 커피

# %%
print("차가운 커피".replace("뜨거운", "미지근한"))
# Out:
# 차가운 커피

# %% [markdown]
# *   대문자와 소문자로 변환된 문자열 생성

# %%
print("내일은 내일의 태양이 뜬다. After all, tommorow is another day.".upper())
# Out:
# 내일은 내일의 태양이 뜬다. AFTER ALL, TOMMOROW IS ANOTHER DAY.

# %%
print("내일은 내일의 태양이 뜬다. After all, tommorow is another day.".lower())
# Out:
# 내일은 내일의 태양이 뜬다. after all, tommorow is another day.

# %%
print("내일은 내일의 태양이 뜬다. After all, tommorow is another day.".swapcase())
# Out:
# 내일은 내일의 태양이 뜬다. aFTER ALL, TOMMOROW IS ANOTHER DAY.

# %% [markdown]
# *   문자열의 종류 확인

# %%
print("day".isalpha())
# Out:
# True

# %%
print("한글".isalpha())
# Out:
# True

# %%
print("韓國".isalpha())
# Out:
# True

# %%
print("한글hangul".isalpha())
# Out:
# True

# %%
print("day3".isalpha())
# Out:
# False

# %%
print("day 3".isalpha())
# Out:
# False

# %%
print("콤마, 세미콜론;".isalpha())
# Out:
# False

# %%
print("123".isdigit())
# Out:
# True

# %%
print("day3".isdigit())
# Out:
# False

# %%
print("123.2".isdigit())
# Out:
# False

# %%
print("0123".isdigit())
# Out:
# True

# %%
print("day3".isalnum())
# Out:
# True

# %%
print("day".isalnum())
# Out:
# True

# %%
print("한글".isalnum())
# Out:
# True

# %%
print("3 days".isalnum())
# Out:
# False

# %%
print("DAY".isupper())
# Out:
# True

# %%
print("DAY".islower())
# Out:
# False

# %%
print("Day".isupper())
# Out:
# False

# %%
print("Day".islower())
# Out:
# False

# %%
print("day".islower())
# Out:
# True

# %%
print("day".isupper())
# Out:
# False

# %% [markdown]
# # Reference: 본 코드는 길벗 출판사의 "파이썬의 정석" 책의 코드를 수업형식에 맞게 응용한 코드입니다.
